# %% [markdown]
# # Wichtige Befehle

# %% [markdown]
# ## venv-Umgebung aktivieren
# - in das Verzeichnis wechseln z.B.
#
# cd C:\Python_Projekte\AI_programming
#
# - venv Umgebung aktivieren
#
# .\venv\Scripts\activate
