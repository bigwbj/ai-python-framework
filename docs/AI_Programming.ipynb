# %% [markdown]
# # Projekt: AI-basierter Python-Agent für automatisierte Softwareentwicklung

# %% [markdown]
# ## 🎯 Ziel des Projekts
# Das Ziel des Projekts ist die Entwicklung eines Frameworks in **Python**, das in **VS Code** erstellt wird und eine Integration mit **GitHub Actions** für CI/CD bietet.
# Das Framework soll später eine Schnittstelle zu einer **AI** enthalten, die definierte Schritte wie Codegenerierung, Tests und Versionierung automatisiert ausführt.
# Der Fokus liegt darauf, eine modulare, wartbare und erweiterbare Architektur zu schaffen, die Anforderungen aus Markdown-Dateien verarbeitet und Workflows abbildet.

# %% [markdown]
# ## ✅ Bisher definierte Anforderungen
# - **Zielgruppe:** Entwickler → Ton technisch und präzise.
# - **Sprache:** Python.
# - **Projektstruktur:**
#   - Ordner für Anforderungen (`/requirements`), Use-Cases (`/use_case`), Tests (`/unit_test`) und Code (`/src`).
# - **Integration:**
#   - GitHub für Versionskontrolle.
#   - GitHub Actions für CI/CD.
# - **Workflow:**
#   - Anforderungen aus Markdown-Dateien einlesen.
#   - Konflikte erkennen und interaktiv mit dem User lösen.
#   - Code generieren und kommentieren.
#   - Unit-Tests ableiten und ausführen.
#   - Änderungen dokumentieren und automatisch zu GitHub pushen.
# - **Fehlerbehandlung:**
#   - Wenn Tests fehlschlagen → Fixes generieren → Prozess wiederholen.
# - **Optimierungsvorschläge:**
#   - Bei unklaren Anforderungen → präzisere Formulierungen vorschlagen.
# - **Dokumentation:**
#   - Ergebnisse als Markdown für Jupyter Notebook.
# - **Best Practices:**
#   - Saubere Architektur, modulare Struktur, CI/CD-Setup mit GitHub Actions.

# %% [markdown]
# ## ✅Input-Format (Markdown)

# %% [markdown]
# ### ✅ Requirements-Dateien:
# ```md
# # Requirement-ID: RQ-001
# ## Beschreibung:
# Kurze, präzise Beschreibung der Anforderung.
# ## KPIs:
# - KPI-1: Beschreibung
# - KPI-2: Beschreibung
# ## Optional:
# - Zugehöriger Use-Case: UC-001
# ```

# %% [markdown]
# ````
# ℹ️ „Optional: Verknüpfe jedes Requirement mit einem Use-Case, um die Nachvollziehbarkeit zu erhöhen.“
# ````

# %% [markdown]
# ### ✅ Use-Case-Dateien:
# ```md
# # Use-Case-ID: UC-001
# ## Beschreibung:
# Kurze Beschreibung des Anwendungsfalls.
# ## Schritte:
# 1. Schritt 1
# 2. Schritt 2
# ```

# %% [markdown]
# ### ✅ Unit-Test-Dateien:
# ```md
# # Test-ID: TST-001
# ## Ziel:
# Was soll getestet werden?
# ## KPIs:
# - KPI-1: Beschreibung
# ```

# %% [markdown]
# ## ✅ Output-Format

# %% [markdown]
# ### ✅ Konfliktbericht (JSON):

# %% [markdown]
# ```json
# {
#   "conflict_id": "C-001",
#   "description": "Beschreibung des Konflikts",
#   "affected_requirements": ["RQ-001", "RQ-002"],
#   "impact": "Mögliche Auswirkungen"
# }
# ```

# %% [markdown]
# ### ✅ Commit-Dokumentation (Markdown):

# %% [markdown]
# ```md
# # Commit-Dokumentation
# ## Änderungen:
# - Geänderte Anforderungen: RQ-001
# - Generierter Code: Modul XYZ
# ## Tests:
# - Erfolgreich: 10
# - Fehlgeschlagen: 0
# ```

# %% [markdown]
# # ✅ Aktueller Prompt

# %% [markdown]
# ```md
# Du bist ein AI-Assistent, der mir hilft, ein Framework in Python zu entwickeln, das in VS Code erstellt wird und GitHub Actions für CI/CD integriert. Das Framework soll später eine Schnittstelle zu einer AI enthalten, um definierte Schritte wie Codegenerierung, Tests und Versionierung automatisiert auszuführen.
#
# ## Deine Aufgaben:
# 1. Architektur & Konzept:
#    - Entwirf die grundlegende Architektur des Frameworks (Ordnerstruktur, Module, Schnittstellen).
#    - Plane die Integration mit VS Code und GitHub.
#    - Definiere, wie die AI-Schnittstelle eingebunden wird (z. B. REST API oder Plugin).
# 2. Schritt-für-Schritt-Anweisungen:
#    - Gib klare, iterative Anleitungen für die Umsetzung:
#      - Projektinitialisierung in VS Code.
#      - Einrichtung von GitHub-Repository.
#      - Konfiguration von GitHub Actions für CI/CD.
#      - Implementierung der Kernmodule.
# 3. Beispielcode:
#    - Liefere Python-Code-Snippets für:
#      - Ordnerstruktur und Initialisierung.
#      - Beispielmodule (z. B. Parser für Markdown-Anforderungen).
#      - GitHub Actions Workflow-Dateien (.yml).
# 4. Best Practices:
#    - Empfehle bewährte Methoden für:
#      - Versionskontrolle.
#      - CI/CD mit GitHub Actions.
#      - Dokumentation (Markdown/Jupyter).
# 5. Output-Format:
#    - Gib alle Ergebnisse als Markdown-Dokumentation aus, die ich in einem Jupyter Notebook verwenden kann.
#    - Struktur:
#      # Projektübersicht
#      ## Architektur
#      (Diagramm oder Beschreibung)
#      ## Schritt-für-Schritt-Anleitung
#      (Liste der Schritte)
#      ## Beispielcode
#      (Code-Snippets)
#      ## Best Practices
#      (Tipps)
#
# ## Zusätzliche Anforderungen:
# - Sprache: Python.
# - CI/CD: GitHub Actions.
# - Dokumentation: Markdown für Jupyter Notebook.
# - Interaktiv: Arbeite iterativ mit mir – frage nach Feedback, bevor du den nächsten Schritt machst.
#
# ```md

# %% [markdown]
# ## ✅ Nächste Schritte
# 1. Architektur und Ordnerstruktur entwerfen.
# 2. Workflow definieren.
# 3. GitHub Actions für CI/CD einrichten.
# 4. AI-Schnittstelle planen.
# 5. Beispielcode für Kernmodule erstellen.

# %% [markdown]
# # 📂 Architektur und Ordnerstruktur des Frameworks
#
# ## ✅ Ziel der Architektur
#
# Die Architektur soll modular, wartbar und erweiterbar sein. Sie bildet die Grundlage für:
# - Verarbeitung von Anforderungen, Use-Cases und Tests aus Markdown-Dateien.
# - Integration einer AI-Schnittstelle für automatisierte Workflows.
# - Nutzung von GitHub für Versionskontrolle und GitHub Actions für CI/CD.
#
# ---
#
# ## ✅ Empfohlene Ordnerstruktur
# ```plaintext
# project-root/
# │
# ├── requirements/        # Enthält Markdown-Dateien mit funktionalen und nicht-funktionalen Anforderungen
# │   └── RQ-001.md
# │
# ├── use_case/            # Enthält Markdown-Dateien mit Use-Cases
# │   └── UC-001.md
# │
# ├── unit_test/           # Enthält Markdown-Dateien mit Testanforderungen und KPIs
# │   └── TST-001.md
# │
# ├── src/                 # Enthält den Python-Quellcode des Frameworks
# │   ├── main.py          # Einstiegspunkt des Frameworks
# │   ├── modules/         # Unterordner für einzelne Module
# │   │   ├── parser.py    # Parser für Markdown-Dateien
# │   │   ├── generator.py # Modul für Codegenerierung
# │   │   ├── tester.py    # Modul für Testausführung
# │   │   └── ai_interface.py # Schnittstelle zur AI
# │
# ├── tests/               # Enthält generierte Unit-Tests
# │   └── test_main.py
# │
# ├── .github/
# │   └── workflows/       # GitHub Actions Workflows für CI/CD
# │       └── ci.yml
# │
# ├── docs/                # Dokumentation (Markdown oder Jupyter Notebooks)
# │   └── architecture.md
# │
# ├── requirements.txt     # Python-Abhängigkeiten
# ├── README.md            # Projektübersicht
# └── setup.py             # Optional für Paketinstallation
# ``

# %% [markdown]
# ✅ Begründung der Struktur
#
# - requirements, use_case, unit_test: Trennung der Eingabedaten für klare Verantwortlichkeiten.
# - src/modules: Modularisierung für Parser, Codegenerator, Tester und AI-Schnittstelle.
# - tests: Separater Bereich für Unit-Tests.
# - .github/workflows: Ermöglicht CI/CD mit GitHub Actions.
# - docs: Für Projektdokumentation und Architekturübersicht.
# - requirements.txt: Verwaltung der Python-Abhängigkeiten.
# - README.md: Einstiegspunkt für Entwickler.

# %% [markdown]
# # 🛠️ GitHub Actions für CI/CD einrichten
# - Ziel: Automatisierte Test und spätere automatisierte Codegenerierung
# - Startpunkt: Einfacher Workflow der bei jedem Push
#   - Python installiert,
# - Abhängigkeiten aus "requirements.txt" installiert
# - Test ausführt

# %% [markdown]
# ## 🔁 Erstellung der Workflow Anweisung für GitHub -> "ci.yml"
# Damit GitHub weiß, welche Actions gemacht werden sollen, müssen diese in dem File "ci.yml" definiert werden.
#
# Die Datei wird dann unter .github/workflow/ci.yml mit folgendem Inhalt erstellt

# %% [markdown]
# ### Was passiert hier?
# - on: Workflow wird bei jedem Push oder Pull Request auf den main Branch ausgelöst.
# - jobs: Definiert die Jobs, die in diesem Workflow ausgeführt werden.
# - Repository checkout: Checkt den Code aus dem Repository aus.
# - Set up Python: Richtet die Python-Umgebung ein.
# - Install dependencies: Installiert die Abhängigkeiten aus der requirements.txt Datei.
# - Run tests: Führt die Tests im tests/ Verzeichnis mit pytest aus.
#
# ### Aufgabe nach der Erstellung: Füge pytest in die datei requirements.txt ein, damit es installiert wird.
# ```yaml
# name: CI Pipeline
# on:
#   push:
#     branches: [ main ]
#   pull_request:
#
# jobs:
#   build-and-test:
#     runs-on: ubuntu-latest
#
#     steps:
#       #1 Repository checkout
#       - name: checkout Repository
#         uses: actions/checkout@v3
#       #2 Set up Python
#       - name: Set up Python
#         uses: actions/setup-python@v4
#         with:
#           python-version: '3.10'
#       #3 Install dependencies
#       - name: Install dependencies
#         run: |
#           python -m pip install --upgrade pip
#           pip install -r requirements.txt
#       #4 Run tests
#       - name: Run tests
#         run: |
#           pytest tests/
# ```

# %% [markdown]
# ## ⚠️ ACHTUNG - mögliche Fehlerquellen
# - Die Datei wurde falsch benannt
# - Die Daten liegen am falschen Ort
# - Nicht alle Daten sind schon im GitHub Repo

# %% [markdown]
# ## Erstellen der requirements.txt Datei im Root-Folder
#
# in der Datei steht aktuell nur
#
# pytest

# %% [markdown]
# ## Erstellen der Testdatei für den ersten CI/CD Test
#
# Dafür wird im Ordner tests die Datei "test_main.py" mit folgendem Inhalt erstellt.
#
# ```python
# import os
#
# def test_project_structure():
#     # Check if .gitignore file exists
#     assert os.path.isfile('.gitignore'), ".gitignore file is missing."
#     # Check if requirements.txt file exists
#     assert os.path.isfile('requirements.txt'), "requirements.txt file is missing."
#
#     # check if folder structure exists
#     assert os.path.exists('requirements'), "requirements folder is missing."
#     # assert os.path.exists('use_case'), "use_case folder is missing."
#     # assert os.path.exists('unit_test'), "unit_test folder is missing."
#     # assert os.path.exists('src'), "src folder is missing."
#     assert os .path.exists('tests'), "tests folder is missing."
#     assert os.path.exists('docs'), "docs folder is missing."
# ```

# %% [markdown]
# ## Test der CI Pipline
# Wenn alle 3 Dateien vollständig vorhanden sind,
# - .github/workflows/ci.yml
# - requirements.txt
# - tests/rest_main.py
# kann der erste Pipeline Test erfolgen.
#
# Hierfür zu GitHub in dein Projekt wechseln und prüfen ob alle Dateien vorhanden sind
# Dann oben im Reiter auf "Actions" klicken und dann sollte dort die CI Pipeline mit dem Testergebnis sichtbar sein.
#
# <img src="images/GitHub_CICD_01.png" width="600">

# %% [markdown]
# # Markdown Parser erstellen

# %% [markdown]
# ## 🚀 Vorgehensplan für die gemeinsame Entwicklung des Markdown‑Parsers
# ## 1️⃣ Zuerst definieren wir das Datenmodell (Domain Objects)
# Bevor wir irgendetwas parsen, müssen wir festlegen:
# - Welche Objekte gibt es?
# - Requirement
# - UseCase
# - TestSpec
# - Welche Felder sind Pflicht?
# - Welche Felder sind optional?
# - Welche Validierungsregeln gelten?
# ### ➡️ Warum zuerst?
# Weil der Parser später exakt diese Objekte erzeugt.
# Und der Codegenerator wiederum genau diese Objekte als Input bekommt.
#
# ## 2️⃣ Dann definieren wir das Markdown‑Format präzise
# Du hast bereits ein Format vorgegeben — wir müssen es jetzt:
# - formal spezifizieren
# - mögliche Varianten/Fehlerfälle definieren
# - entscheiden, wie streng der Parser sein soll
# - festlegen, wie wir mit fehlenden Feldern umgehen
# ### ➡️ Das wird später wichtig für:
# - Konflikterkennung
# - AI‑gestützte Präzisierung
# - automatische Codegenerierung
#
# ## 3️⃣ Parser‑Strategie festlegen
# Wir entscheiden gemeinsam:
# - Regex‑basiert?
# - Zeilenweises State‑Machine‑Parsing?
# - Markdown‑AST‑Parser (z. B. markdown-it-py)?
# - Mischung aus beidem?
# ### Ich empfehle eine State‑Machine, weil sie:
# - robust ist
# - gut erweiterbar
# - perfekt zu deinen strukturierten Markdown‑Dateien passt
#
# ## 4️⃣ Parser‑Skeleton implementieren
# Wir starten mit:
# - MarkdownParser Klasse
# - Methoden:
# - parse_requirements()
# - parse_use_cases()
# - parse_tests()
# - _parse_single_requirement()
# - _parse_single_use_case()
# - _parse_single_test()
# ### ➡️ Erst minimal, dann iterativ erweitern

# %% [markdown]
# # 🧩 Erweiterte Datenmodell‑Definition für Requirements
# ## 🎯 Ziel
# Ein Requirement soll zwei Ebenen haben:
# - Headline / Summary
# → Kurz, prägnant, 1 Satz, beschreibt den Kern der Anforderung
# - Description
# → Ausführliche Beschreibung, Hintergrund, Kontext, Details
# Zusätzlich soll die AI später:
# - aus der Description automatisch eine Headline ableiten können
# - prüfen können, ob eine vorhandene Headline konsistent ist
# - Verbesserungsvorschläge machen können

# %% [markdown]
# ## 📐 Vorschlag für das neue Requirement‑Model
# ```python
# @dataclass
# class Requirement:
#     id: str
#     title: str # Kurztext / Headline
#     description: str # Ausführliche Beschreibung
#     kpis: list[str] # Definition der Einzuhaltenden KPIs
#     use_case_id: Optional[str] = None # Für spätere Erweiterungen
#     metadata: dict = None # Für spätere Erweiterungen
#
# ```
# ## Warum ein metadata‑Feld?
# Damit du später flexibel bist, z. B.:
# - Priorität (prio: high/medium/low)
# - Kategorie (functional, non-functional)
# - Tags (security, performance, …`)
# - AI‑Bewertungen (ai_consistency_score, ai_suggested_title, …)
# Das macht das Modell zukunftssicher, ohne dass wir ständig neue Felder hinzufügen müssen.

# %% [markdown]
# 🧭 Markdown‑Format für Requirements (erweitert)
# Ich schlage folgende Struktur vor:
# ```md
# # Requirement-ID: RQ-001
# ## Title:
# Kurzbeschreibung der Anforderung
#
# ## Beschreibung:
# Ausführliche Beschreibung der Anforderung.
# Mehrere Sätze möglich.
#
# ## KPIs:
# - KPI-1: Beschreibung
# - KPI-2: Beschreibung
#
# ## Optional:
# - Zugehöriger Use-Case: UC-001
# - Tags: performance, backend
# - Prio: High

# %% [markdown]
# 🧠 Wie die AI später damit arbeitet
# 1. Wenn Title fehlt
# AI generiert automatisch einen Vorschlag:
# „Generiere eine prägnante Überschrift basierend auf der Beschreibung.“
#
# 2. Wenn Title vorhanden ist
# AI prüft Konsistenz:
# - Passt die Headline zum Inhalt?
# - Ist sie zu lang?
# - Ist sie zu allgemein?
# - Fehlen wichtige Begriffe?
# 3. Optional
# AI kann:
# - alternative Titel vorschlagen
# - Titel nach Styleguide anpassen
# - Titel in Kategorien einordnen

# %% [markdown]
# 🛠️ Parser‑Erweiterung (Konzept)
# ```md
# Der Parser muss:
# - ## Title: erkennen
# - ## Beschreibung: erkennen
# - Mehrzeilige Inhalte korrekt sammeln
# - Fehlende Titel erkennen
# - Zusätzliche Felder in ## Optional: dynamisch einlesen
# Beispiel‑Parsing‑Logik (vereinfacht)
# ```
#
# ```python
# elif stripped.startswith("## Title"):
#     current_section = "title"
# elif stripped.startswith("## Beschreibung"):
#     current_section = "description"
# elif current_section == "title":
#     title_lines.append(stripped)
# elif current_section == "description":
#     description_lines.append(stripped)
# ```

# %% [markdown]
# # Prompt für die nächste Sitzung
# ```md
# Ich setze ein bestehendes Projekt fort und möchte dort weitermachen, wo ich zuletzt aufgehört habe.
#
# ## Projektkontext:
# Ich entwickle ein Framework in Python, das in VS Code erstellt wird und GitHub Actions für CI/CD nutzt.
# Das Framework soll später eine AI-Schnittstelle enthalten, die automatisiert:
# - Code generiert
# - Tests ableitet und ausführt
# - Versionierung und Dokumentation übernimmt
#
# Die Projektstruktur, CI-Pipeline, erste Tests und Dokumentation sind bereits angelegt.
# Ich habe eine umfangreiche Markdown-Dokumentation, die die Architektur, Ordnerstruktur, CI/CD-Setup und erste Module beschreibt.
#
# ## Aktueller Stand:
# Wir haben gemeinsam begonnen, einen **Markdown-Parser** zu entwickeln, der Requirements, Use-Cases und Tests aus Markdown-Dateien einliest.
# Wir haben das Datenmodell erweitert:
#
# ### Requirement-Modell:
# - id: str
# - title: str (Kurzbeschreibung / Headline)
# - description: str (ausführliche Beschreibung)
# - kpis: list[str]
# - use_case_id: Optional[str]
# - metadata: dict (für spätere Erweiterungen)
#
# Ziel ist es, dass die AI später:
# - aus der Beschreibung automatisch eine passende Überschrift ableiten kann
# - vorhandene Überschriften auf Konsistenz prüfen kann
#
# Wir wollten als nächstes:
# - das finale Markdown-Format festlegen
# - den Parser-Skeleton implementieren
# - entscheiden, wie flexibel der Parser mit Varianten umgehen soll (Option A/B/C)
#
# ## Deine Aufgabe:
# Bitte knüpfe an diesen Stand an und hilf mir, den Markdown-Parser weiterzuentwickeln.
# Ich möchte als nächstes:
# 1. Das finale Markdown-Format für Requirements, Use-Cases und Tests festlegen
# 2. Den Parser-Skeleton implementieren
# 3. Die Parsing-Strategie (State-Machine) gemeinsam ausarbeiten
# 4. Validierungsregeln definieren
# 5. Den Parser so gestalten, dass er später für automatische Codegenerierung genutzt werden kann
#
# Arbeite iterativ mit mir, stelle Rückfragen, wenn nötig, und liefere klare, technische Vorschläge.
# ```
